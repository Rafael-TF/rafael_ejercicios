# %%
import pandas as pd

df = pd.read_csv('../Data/iris.csv')

df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
df['Clase'].value_counts()
# Out:
# Clase
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
mapeo_clase = {
    'Iris-setora' : 1,
    'Iris-versicolor' : 2,
    'Iris-virginica' : 3
}

df['Clase'] = df['Clase'].map(mapeo_clase)
df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  Clase
# 0           5.1           3.5           1.4           0.2    NaN
# 1           4.9           3.0           1.4           0.2    NaN
# 2           4.7           3.2           1.3           0.2    NaN
# 3           4.6           3.1           1.5           0.2    NaN
# 4           5.0           3.6           1.4           0.2    NaN

# %%
# Matriz correlación

correlacion = df.corr()
correlacion
# Out:
#               Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo     Clase
# Largo Sepalo      1.000000     -0.109369      0.871754      0.817954  0.494305
# Ancho Sepalo     -0.109369      1.000000     -0.420516     -0.356544  0.308080
# Largo Petalo      0.871754     -0.420516      1.000000      0.962757  0.786424
# Ancho Petalo      0.817954     -0.356544      0.962757      1.000000  0.828129
# Clase             0.494305      0.308080      0.786424      0.828129  1.000000

# %%
# Mostrar la matriz de correlación con Seaborn
import seaborn as sns

sns.heatmap(correlacion, annot=True, cmap = 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Encoding con .get_dummies()

# %%
df = pd.read_csv('../Data/iris.csv')

# %%
pd.get_dummies(df)
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# 0             5.1           3.5           1.4           0.2
# 1             4.9           3.0           1.4           0.2
# 2             4.7           3.2           1.3           0.2
# 3             4.6           3.1           1.5           0.2
# 4             5.0           3.6           1.4           0.2
# ..            ...           ...           ...           ...
# 145           6.7           3.0           5.2           2.3
# 146           6.3           2.5           5.0           1.9
# 147           6.5           3.0           5.2           2.0
# 148           6.2           3.4           5.4           2.3
# 149           5.9           3.0           5.1           1.8
#
#      Clase_Iris-setosa  Clase_Iris-versicolor  Clase_Iris-virginica
# 0                 True                  False                 False
# 1                 True                  False                 False
# 2                 True                  False                 False
# 3                 True                  False                 False
# 4                 True                  False                 False
# ..                 ...                    ...                   ...
# 145              False                  False                  True
# 146              False                  False                  True
# 147              False                  False                  True
# 148              False                  False                  True
# 149              False                  False                  True
#
# [150 rows x 7 columns]

# %%
df_encoded = pd.get_dummies(df, columns=['Clase'])
df_encoded
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  Clase_2.0  \
# 0             5.1           3.5           1.4           0.2      False
# 1             4.9           3.0           1.4           0.2      False
# 2             4.7           3.2           1.3           0.2      False
# 3             4.6           3.1           1.5           0.2      False
# 4             5.0           3.6           1.4           0.2      False
# ..            ...           ...           ...           ...        ...
# 145           6.7           3.0           5.2           2.3      False
# 146           6.3           2.5           5.0           1.9      False
# 147           6.5           3.0           5.2           2.0      False
# 148           6.2           3.4           5.4           2.3      False
# 149           5.9           3.0           5.1           1.8      False
#
#      Clase_3.0
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 145       True
# 146       True
# 147       True
# 148       True
# 149       True
#
# [150 rows x 6 columns]

# %%
correlacion = df_encoded.corr()
sns.heatmap(correlacion, annot=True, cmap = 'viridis')
# Out:
# <Axes: >
